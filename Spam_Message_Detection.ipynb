# %% [markdown]
# <a href="https://colab.research.google.com/github/KavithaJ20/Spam_Message_Detection/blob/main/Spam_Message_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import urllib.request
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Download dataset automatically
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip"
urllib.request.urlretrieve(url, "spam.zip")

# Extract zip
import zipfile
with zipfile.ZipFile("spam.zip", 'r') as zip_ref:
    zip_ref.extractall()

# Load dataset
data = pd.read_csv("SMSSpamCollection", sep='\t', names=["label", "message"])

# Convert labels
data['label'] = data['label'].map({'spam': 1, 'ham': 0})

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    data['message'], data['label'], test_size=0.2, random_state=42
)

# Vectorization
vectorizer = TfidfVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Train model
model = MultinomialNB()
model.fit(X_train_vec, y_train)

# Test accuracy
y_pred = model.predict(X_test_vec)
print("Model Accuracy:", accuracy_score(y_test, y_pred))

# Custom message test
message = ["WINNER!! Claim your FREE prize now. Call 09061701461"]
message_vec = vectorizer.transform(message)
prediction = model.predict(message_vec)

print("Prediction:", "Spam" if prediction[0] == 1 else "Not Spam")
# Out:
# Model Accuracy: 0.97847533632287
# Prediction: Spam

# %% [markdown]
# The previous cell failed because the file `spam.csv` was not found. I'll download a common version of the 'SMS Spam Collection Dataset' that is often used for this task.
